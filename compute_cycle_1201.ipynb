# %%
from pathlib import Path
import os
import numpy as np
from easydict import EasyDict as edict
from pprint import pprint
import argparse

# %%
parser = argparse.ArgumentParser("Compute ")
parser.add_argument('--input_path', type=str, default='./result', help="Path to store Cycle list calculated by ACA")
parser.add_argument('--output_dir', type=str, default='./output', help="output directory")
# Out:
# _StoreAction(option_strings=['--output_dir'], dest='output_dir', nargs=None, const=None, default='./ACA2/resource', type=<class 'str'>, choices=None, help='output directory', metavar=None)

# %%
def parsing_sys_result(input_path):
    if not isinstance(input_path, Path):
        # input_path's string
        input_path = Path(input_path)
        result_cycle_path = input_path
    else:
        result_cycle_path = input_path
        
    entire_parsing_dict = edict()
    network_name = []
    for test_file in result_cycle_path.glob('*'):
        with open(test_file, 'r') as f:
            result_lines = f.readlines()
        temp_parsing_dict = edict()

        for i, line in enumerate(result_lines):
            line_list = line.split(' ')
            if "Systolic" in line:
                row = int(line_list[line_list.index('row')+2]) # get row
                col = int(line_list[line_list.index('col')+2]) # get row
                temp_parsing_dict[f'{row}_{col}'] = edict()

            if 'DNN' in line and 'cycle' not in result_lines[i+1]:
                model_name = line_list[-1].split(".txt")[0]
                temp_parsing_dict[f'{row}_{col}'][model_name] = edict()
                cycle_list = result_lines[i+1].rstrip('\n').split(' ')
                if '' in cycle_list:
                    print(cycle_list)
                    cycle_list = cycle_list[:-1]
                temp_parsing_dict[f'{row}_{col}'][model_name]['layer_cycle'] = list(map(int, cycle_list))

                #parsing_dict[f'{row}_{col}'][line_list[-1].split(".txt")[0]]['layer_cycle'] = list(map(int, result_lines[i+1].split(' ')[:-1]))

            if 'DNN' in line and 'cycle' in result_lines[i+1]:
                temp_parsing_dict[f'{row}_{col}'][model_name]['total_cycle'] = result_lines[i+1].split()[-1].split('\n')[0]
                network_name.append(model_name)

        for row_col_val in temp_parsing_dict.keys():
            if not hasattr(entire_parsing_dict, row_col_val):
                entire_parsing_dict[row_col_val]  = edict()

            if not hasattr(entire_parsing_dict[row_col_val], model_name):
                entire_parsing_dict[row_col_val][model_name] = edict()
            entire_parsing_dict[row_col_val][model_name]['layer_cycle'] = temp_parsing_dict[row_col_val][model_name]['layer_cycle']
    network_name = set(network_name)
    
    return entire_parsing_dict, network_name

# %%
entire_parsing_dict
# Out:
# {'64_64': {'resnet50_summary': {'layer_cycle': [9941904,
#     633374,
#     683550,
#     2533496,
#     652190,
#     683550,
#     2533496,
#     652190,
#     683550,
#     2533496,
#     1304380,
#     142222,
#     364088,
#     110222,
#     142222,
#     364088,
#     110222,
#     142222,
#     364088,
#     110222,
#     142222,
#     364088,
#     220444,
#     78788,
#     85776,
#     42948,
#     78788,
#     85776,
#     42948,
#     78788,
#     85776,
#     42948,
#     78788,
#     85776,
#     42948,
#     78788,
#     85776,
#     42948,
#     78788,
#     85776,
#     85896,
#     76816,
#     45120,
#     35856,
#     76816,
#     45120,
#     35856,
#     76816,
#     45120,
#     34386]},
#   't_summary': {'layer_cycle': [41344,
#     41344,
#     41344,
#     67328,
#     37760,
#     165376,
#     90496,
#     41344,
#     41344,
#     41344,
#     67328,
#     37760,
#     165376,
#     90496,
#     446]},
#   'tiny_bert_summary': {'layer_cycle': [41344,
#     41344,
#     41344,
#     67328,
#     37760,
#     165376,
#     90496,
#     41344,
#     41344,
#     41344,
#     67328,
#     37760,
#     165376,
#     90496,
#     446]}},
#  '128_128': {'resnet50_summary': {'layer_cycle': [4970952,
#     316687,
#     341775,
#     645918,
#     326095,
#     341775,
#     645918,
#     326095,
#     341775,
#     645918,
#     332367,
#     38547,
#     100940,
#     30227,
#     38547,
#     100940,
#     30227,
#     38547,
#     100940,
#     30227,
#     38547,
#     100940,
#     60454,
#     23352,
#     27872,
#     13112,
#     23352,
#     27872,
#     13112,
#     23352,
#     27872,
#     13112,
#     23352,
#     27872,
#     13112,
#     23352,
#     27872,
#     13112,
#     23352,
#     27872,
#     26224,
#     19332,
#     11792,
#     9092,
#     19332,
#     11792,
#     9092,
#     19332,
#     11792,
#     18122]},
#   't_summary': {'layer_cycle': [11360,
#     11360,
#     11360,
#     23232,
#     23232,
#     45440,
#     23648,
#     11360,
#     11360,
#     11360,
#     23232,
#     23232,
#     45440,
#     23648,
#     287]},
#   'tiny_bert_summary': {'layer_cycle': [11360,
#     11360,
#     11360,
#     23232,
#     23232,
#     45440,
#     23648,
#     11360,
#     11360,
#     11360,
#     23232,
#     23232,
#     45440,
#     23648,
#     287]}},
#  '256_256': {'resnet50_summary': {'layer_cycle': [2498020,
#     167783,
#     180583,
#     170919,
#     172583,
#     180583,
#     170919,
#     172583,
#     180583,
#     170919,
#     172647,
#     20921,
#     30386,
#     16441,
#     20921,
#     30386,
#     16441,
#     20921,
#     30386,
#     16441,
#     20921,
#     30386,
#     17881,
#     6158,
#     8248,
#     3598,
#     6158,
#     8248,
#     3598,
#     6158,
#     8248,
#     3598,
#     6158,
#     8248,
#     3598,
#     6158,
#     8248,
#     3598,
#     6158,
#     8248,
#     7196,
#     9922,
#     6920,
#     4802,
#     9922,
#     6920,
#     4802,
#     9922,
#     6920,
#     9894]},
#   't_summary': {'layer_cycle': [14560,
#     14560,
#     14560,
#     23232,
#     23232,
#     30912,
#     26848,
#     14560,
#     14560,
#     14560,
#     23232,
#     23232,
#     30912,
#     26848,
#     319]},
#   'tiny_bert_summary': {'layer_cycle': [14560,
#     14560,
#     14560,
#     23232,
#     23232,
#     30912,
#     26848,
#     14560,
#     14560,
#     14560,
#     23232,
#     23232,
#     30912,
#     26848,
#     319]}}}

# %%
parsing_dict, network_name = parsing_sys_result('./result')
network_name = set(network_name)
print(parsing_dict)

sys_path = Path('./systolic.txt')
with open(sys_path, "r") as f:
    result_lines = f.readlines()

sys_name_list = []
for line in result_lines:
    line_list = line.split(' ')
    row = line_list[0]
    col = line_list[1]
    num = line_list[2]
    sys_name_list.append([f'{row}_{col}', num])
# Out:
# ['9941904', '633374', '683550', '2533496', '652190', '683550', '2533496', '652190', '683550', '2533496', '1304380', '142222', '364088', '110222', '142222', '364088', '110222', '142222', '364088', '110222', '142222', '364088', '220444', '78788', '85776', '42948', '78788', '85776', '42948', '78788', '85776', '42948', '78788', '85776', '42948', '78788', '85776', '42948', '78788', '85776', '85896', '76816', '45120', '35856', '76816', '45120', '35856', '76816', '45120', '34386', '']
# ['4970952', '316687', '341775', '645918', '326095', '341775', '645918', '326095', '341775', '645918', '332367', '38547', '100940', '30227', '38547', '100940', '30227', '38547', '100940', '30227', '38547', '100940', '60454', '23352', '27872', '13112', '23352', '27872', '13112', '23352', '27872', '13112', '23352', '27872', '13112', '23352', '27872', '13112', '23352', '27872', '26224', '19332', '11792', '9092', '19332', '11792', '9092', '19332', '11792', '18122', '']
# ['2498020', '167783', '180583', '170919', '172583', '180583', '170919', '172583', '180583', '170919', '172647', '20921', '30386', '16441', '20921', '30386', '16441', '20921', '30386', '16441', '20921', '30386', '17881', '6158', '8248', '3598', '6158', '8248', '3598', '6158', '8248', '3598', '6158', '8248', '3598', '6158', '8248', '3598', '6158', '8248', '7196', '9922', '6920', '4802', '9922', '6920', '4802', '9922', '6920', '9894', '']
# ['41344', '41344', '41344', '67328', '37760', '165376', '90496', '41344', '41344', '41344', '67328', '37760', '165376', '90496', '446', '']
# ['11360', '11360', '11360', '23232', '23232', '45440', '23648', '11360', '11360', '11360', '23232', '23232', '45440', '23648', '287', '']
# ['14560', '14560', '14560', '23232', '23232', '30912', '26848', '14560', '14560', '14560', '23232', '23232', '30912', '26848', '319', '']
# ['41344', '41344', '41344', '67328', '37760', '165376', '90496', '41344', '41344', '41344', '67328', '37760', '165376', '90496', '446', '']
# ['11360', '11360', '11360', '23232', '23232', '45440', '23648', '11360', '11360', '11360', '23232', '23232', '45440', '23648', '287', '']
# ['14560', '14560', '14560', '23232', '23232', '30912', '26848', '14560', '14560', '14560', '23232', '23232', '30912', '26848', '319', '']
# {'64_64': {'resnet50_summary': {'layer_cycle': [9941904, 633374, 683550, 2533496, 652190, 683550, 2533496, 652190, 683550, 2533496, 1304380, 142222, 364088, 110222, 142222, 364088, 110222, 142222, 364088, 110222, 142222, 364088, 220444, 78788, 85776, 42948, 78788, 85776, 42948, 78788, 85776, 42948, 78788, 85776, 42948, 78788, 85776, 42948, 78788, 85776, 85896, 76816, 45120, 35856, 76816, 45120, 35856, 76816, 45120, 34386]}, 't_summary': {'layer_cycle': [41344, 41344, 41344, 67328, 37760, 165376, 90496, 41344, 41344, 41344, 67328, 37760, 165376, 90496, 446]}, 'tiny_bert_summary': {'layer_cycle': [41344, 41344, 41344, 67328, 37760, 165376, 90496, 41344, 41344, 41344, 67328, 37760, 165376, 90496, 446]}}, '128_128': {'resnet50_summary': {'layer_cycle': [4970952, 316687, 341775, 645918, 326095, 341775, 645918, 326095, 341775, 645918, 332367, 38547, 100940, 30227, 38547, 100940, 30227, 38547, 100940, 30227, 38547, 100940, 60454, 23352, 27872, 13112, 23352, 27872, 13112, 23352, 27872, 13112, 23352, 27872, 13112, 23352, 27872, 13112, 23352, 27872, 26224, 19332, 11792, 9092, 19332, 11792, 9092, 19332, 11792, 18122]}, 't_summary': {'layer_cycle': [11360, 11360, 11360, 23232, 23232, 45440, 23648, 11360, 11360, 11360, 23232, 23232, 45440, 23648, 287]}, 'tiny_bert_summary': {'layer_cycle': [11360, 11360, 11360, 23232, 23232, 45440, 23648, 11360, 11360, 11360, 23232, 23232, 45440, 23648, 287]}}, '256_256': {'resnet50_summary': {'layer_cycle': [2498020, 167783, 180583, 170919, 172583, 180583, 170919, 172583, 180583, 170919, 172647, 20921, 30386, 16441, 20921, 30386, 16441, 20921, 30386, 16441, 20921, 30386, 17881, 6158, 8248, 3598, 6158, 8248, 3598, 6158, 8248, 3598, 6158, 8248, 3598, 6158, 8248, 3598, 6158, 8248, 7196, 9922, 6920, 4802, 9922, 6920, 4802, 9922, 6920, 9894]}, 't_summary': {'layer_cycle': [14560, 14560, 14560, 23232, 23232, 30912, 26848, 14560, 14560, 14560, 23232, 23232, 30912, 26848, 319]}, 'tiny_bert_summary': {'layer_cycle': [14560, 14560, 14560, 23232, 23232, 30912, 26848, 14560, 14560, 14560, 23232, 23232, 30912, 26848, 319]}}}

# %%
network_name
# Out:
# {'resnet50_summary', 't_summary', 'tiny_bert_summary'}

# %%
class Systolic():
    def __init__(self, sys_name, sys_idx):
        self.sys_name = sys_name
        self.sys_idx = sys_idx
        self.run_systolic_cycle = 0
    
    def __str__(self):
        return f"{self.sys_name}, index {self.sys_idx}"
    
    def __repr__(self):
        return f"array type (sys_name): {self.sys_name}, index (sys_idx): {self.sys_idx}"

    def finish_layer_print(self, network_name, idx):
        print(f"sys name : {self.sys_name}_{self.sys_idx}, network_name's_idx : {network_name}_{idx-1} finish")
        
    def update_run_systolic_cycle(self, cycle):
        self.run_systolic_cycle += cycle

# %%
class Network():
    def __init__(self, parsing_dict, network_name, verbose=True):
        self.name = network_name
        self.network_cycle = edict()
        self.remain_total_cycle = edict()
        
        for sys_index in parsing_dict.keys():
            self.network_cycle[sys_index] = parsing_dict[sys_index][self.name]['layer_cycle']
            self.remain_total_cycle[sys_index] = sum(self.network_cycle[sys_index])
        print(self.remain_total_cycle)
        self.current_running_idx = 0
        self.current_cycle = 0
        self.systolic = None
        self.verbose = verbose
    def get_remain_total_cycle(self):
        return [(sys_name, self.remain_total_cycle[sys_name] + self.current_cycle) for sys_name in self.remain_total_cycle.keys()]
    
    def finish_layer(self, close_cycle):
        """
        finish i idx layer result and re-calculating remain_total_cycle
        """
        if self.verbose:
            print("finish layer")
        for sys_index in self.remain_total_cycle.keys():
            self.remain_total_cycle[sys_index] = sum(self.network_cycle[sys_index][self.current_running_idx:])
        self.current_cycle = 0
        self.systolic.finish_layer_print(self.name, self.current_running_idx)
        self.systolic.update_run_systolic_cycle(self.network_cycle[sys_index][self.current_running_idx-1])
        self.del_systolic()

    def get_current_remain_cycle(self, pre_compute_cycle=0):
        if self.verbose:
            print(f"{self.name}'s idx {self.current_running_idx-1} get current remain cycle")
            if pre_compute_cycle > 0:
                print(f"layer cycle {self.current_cycle} - {pre_compute_cycle} = {self.current_cycle - pre_compute_cycle}")
            else:
                print(f"layer cycle {self.current_cycle}")
            curr_sys_name = self.systolic.sys_name
            self.current_cycle = self.current_cycle - pre_compute_cycle
        else:
            curr_sys_name = self.systolic.sys_name
            self.current_cycle = self.current_cycle - pre_compute_cycle
        
        return self.current_cycle
    
    def set_layer_and_current_cycle(self):
        curr_sys_name = self.systolic.sys_name
        self.current_cycle = self.network_cycle[curr_sys_name][self.current_running_idx-1]
        if self.verbose:
            print("current systolic name :", curr_sys_name)
            print(f"current layer's  idx and cycle : {self.current_running_idx-1}, {self.current_cycle}")
        return self.current_cycle
        
    
    def set_systolic(self, systolic):
        self.systolic = systolic
        self.current_running_idx +=1
        for sys_index in self.remain_total_cycle.keys():
            self.remain_total_cycle[sys_index] = sum(self.network_cycle[sys_index][self.current_running_idx:])
    
    def del_systolic(self):
        self.systolic = None

# %%
def set_layer_and_calculate(list_network, sys_list, i, output_cycle = [], verbose=True):
    current_pool = []
    current_total_cycle_list = []
    most_powerful_sys = sys_list[0]

    for i in range(len(list_network)):
        if list_network[i].remain_total_cycle[most_powerful_sys.sys_name] ==0:
            print("********"*20)
            print("finished network : ", list_network[i].name)
            print("remove network")
            print("********"*20)
            list_network.pop(i)
    
    if len(list_network) == 0:
        print("########## finish entire layer ################")
        print("total using cycle : ")
        print("########## finish entire layer ################")
        return
    
    # calculate remain cycle in most powerful systolic array
    for network in list_network:
        current_total_cycle_list.append(network.remain_total_cycle[most_powerful_sys.sys_name])
    print("======"*20)
    print("using most powerful cycle in time ", i)
    print([network.name for network in list_network])
    print(current_total_cycle_list)
    print("======"*20)
    
    sorted_idx = np.argsort(current_total_cycle_list)[::-1] # required cycle descent sorting
    
    if verbose:
        print("======"*20)
        print(f"Set {i} time in network's cycle in using systolic array")
        for i, network in enumerate(list_network):
            print(network.name)
            print(network.get_remain_total_cycle())
            print("======"*20)
    

    for i, systolic in enumerate(sys_list): # descent layer
        if i >= len(sorted_idx):
            break
        if list_network[sorted_idx[i]].systolic is None:
            list_network[sorted_idx[i]].set_systolic(systolic)
            list_network[sorted_idx[i]].set_layer_and_current_cycle()

    for network in list_network:
        print("======"*20)
        current_pool.append(network.get_current_remain_cycle())
        print("======"*20)
    current_pool = np.array(current_pool)
    min_idx_arr = np.argmin(current_pool)
    min_idx_arr = np.where(current_pool == current_pool[min_idx_arr])[0] # min_idx is np.array and same end cycle to compute 
    
    for min_idx in min_idx_arr:
        print(min_idx)
        close_cycle = current_pool[min_idx]
        print("======"*20)
        print("current layer cycle in systolic array")
        print([f"{sys.sys_name}_{sys.sys_idx}"for sys in sys_list]) # Sorted systolic array in order of good performance
        print(current_pool)
        print("======"*20)
        print("closed systolic idx :", min_idx, sys_list[min_idx])
        print("Using cycle: ", close_cycle)

        print("======"*20)

        list_network[min_idx].finish_layer(close_cycle)
        print("======"*20)
    output_cycle.append(close_cycle)
    
    for i, network in enumerate(list_network):
        print(network.name)
        if i in min_idx_arr:
            print("finished layer")
            print("======"*20)
            print(network.get_remain_total_cycle())
            print("======"*20)
    
        else:
            print("======"*20)
            print(network.get_current_remain_cycle(close_cycle))
            print("======"*20)

# %%
sys_list = []
for sys_name in sys_name_list:
    for i in range(int(sys_name[1])):
        sys_list.append(Systolic(sys_name[0], i))
sys_list.reverse()
list_network=[]
for i, key in enumerate(network_name):
    list_network.append(Network(parsing_dict, key))
# Out:
# {'64_64': 7200, '128_128': 3600, '256_256': 2880}
# {'64_64': 3600, '128_128': 2160, '256_256': 1440}

# %%
output_cycle = []
for i in range(20):
    set_layer_and_calculate(list_network, sys_list, i,output_cycle)
# Out:
# ========================================================================================================================
# using most powerful cycle in time  1
# ['resnet50_summary', 'resnet18_summary']
# [2880, 1440]
# ========================================================================================================================
# ========================================================================================================================
# Set 1 time in network's cycle in using systolic array
# resnet50_summary
# [('64_64', 7200), ('128_128', 3600), ('256_256', 2880)]
# ========================================================================================================================
# resnet18_summary
# [('64_64', 3600), ('128_128', 2160), ('256_256', 1440)]
# ========================================================================================================================
# current systolic name : 256_256
# current layer's  idx and cycle : 0, 80
# current systolic name : 128_128
# current layer's  idx and cycle : 0, 60
# ========================================================================================================================
# resnet50_summary's idx 0 get current remain cycle
# layer cycle 80
# ========================================================================================================================
# ========================================================================================================================
# resnet18_summary's idx 0 get current remain cycle
# layer cycle 60
# ========================================================================================================================
# 1
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [80 60]
# ========================================================================================================================
# closed systolic idx : 1 128_128, index 0
# Using cycle:  60
# ========================================================================================================================
# finish layer
# sys name : 128_128_0, network_name's_idx : resnet18_summary_0 finish
# ========================================================================================================================
# resnet50_summary
# ========================================================================================================================
# resnet50_summary's idx 0 get current remain cycle
# layer cycle 80 - 60 = 20
# 20
# ========================================================================================================================
# resnet18_summary
# finished layer
# ========================================================================================================================
# [('64_64', 3500), ('128_128', 2100), ('256_256', 1400)]
# ========================================================================================================================
# ========================================================================================================================
# using most powerful cycle in time  1
# ['resnet50_summary', 'resnet18_summary']
# [2800, 1400]
# ========================================================================================================================
# ========================================================================================================================
# Set 1 time in network's cycle in using systolic array
# resnet50_summary
# [('64_64', 7020), ('128_128', 3520), ('256_256', 2820)]
# ========================================================================================================================
# resnet18_summary
# [('64_64', 3500), ('128_128', 2100), ('256_256', 1400)]
# ========================================================================================================================
# current systolic name : 128_128
# current layer's  idx and cycle : 1, 120
# ========================================================================================================================
# resnet50_summary's idx 0 get current remain cycle
# layer cycle 20
# ========================================================================================================================
# ========================================================================================================================
# resnet18_summary's idx 1 get current remain cycle
# layer cycle 120
# ========================================================================================================================
# 0
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [ 20 120]
# ========================================================================================================================
# closed systolic idx : 0 256_256, index 0
# Using cycle:  20
# ========================================================================================================================
# finish layer
# sys name : 256_256_0, network_name's_idx : resnet50_summary_0 finish
# ========================================================================================================================
# resnet50_summary
# finished layer
# ========================================================================================================================
# [('64_64', 7000), ('128_128', 3500), ('256_256', 2800)]
# ========================================================================================================================
# resnet18_summary
# ========================================================================================================================
# resnet18_summary's idx 1 get current remain cycle
# layer cycle 120 - 20 = 100
# 100
# ========================================================================================================================
# ========================================================================================================================
# using most powerful cycle in time  1
# ['resnet50_summary', 'resnet18_summary']
# [2800, 1320]
# ========================================================================================================================
# ========================================================================================================================
# Set 1 time in network's cycle in using systolic array
# resnet50_summary
# [('64_64', 7000), ('128_128', 3500), ('256_256', 2800)]
# ========================================================================================================================
# resnet18_summary
# [('64_64', 3400), ('128_128', 2080), ('256_256', 1420)]
# ========================================================================================================================
# current systolic name : 256_256
# current layer's  idx and cycle : 1, 160
# ========================================================================================================================
# resnet50_summary's idx 1 get current remain cycle
# layer cycle 160
# ========================================================================================================================
# ========================================================================================================================
# resnet18_summary's idx 1 get current remain cycle
# layer cycle 100
# ========================================================================================================================
# 1
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [160 100]
# ========================================================================================================================
# closed systolic idx : 1 128_128, index 0
# Using cycle:  100
# ========================================================================================================================
# finish layer
# sys name : 128_128_0, network_name's_idx : resnet18_summary_1 finish
# ========================================================================================================================
# resnet50_summary
# ========================================================================================================================
# resnet50_summary's idx 1 get current remain cycle
# layer cycle 160 - 100 = 60
# 60
# ========================================================================================================================
# resnet18_summary
# finished layer
# ========================================================================================================================
# [('64_64', 3300), ('128_128', 1980), ('256_256', 1320)]
# ========================================================================================================================
# ========================================================================================================================
# using most powerful cycle in time  1
# ['resnet50_summary', 'resnet18_summary']
# [2640, 1320]
# ========================================================================================================================
# ========================================================================================================================
# Set 1 time in network's cycle in using systolic array
# resnet50_summary
# [('64_64', 6660), ('128_128', 3360), ('256_256', 2700)]
# ========================================================================================================================
# resnet18_summary
# [('64_64', 3300), ('128_128', 1980), ('256_256', 1320)]
# ========================================================================================================================
# current systolic name : 128_128
# current layer's  idx and cycle : 2, 180
# ========================================================================================================================
# resnet50_summary's idx 1 get current remain cycle
# layer cycle 60
# ========================================================================================================================
# ========================================================================================================================
# resnet18_summary's idx 2 get current remain cycle
# layer cycle 180
# ========================================================================================================================
# 0
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [ 60 180]
# ========================================================================================================================
# closed systolic idx : 0 256_256, index 0
# Using cycle:  60
# ========================================================================================================================
# finish layer
# sys name : 256_256_0, network_name's_idx : resnet50_summary_1 finish
# ========================================================================================================================
# resnet50_summary
# finished layer
# ========================================================================================================================
# [('64_64', 6600), ('128_128', 3300), ('256_256', 2640)]
# ========================================================================================================================
# resnet18_summary
# ========================================================================================================================
# resnet18_summary's idx 2 get current remain cycle
# layer cycle 180 - 60 = 120
# 120
# ========================================================================================================================
# ========================================================================================================================
# using most powerful cycle in time  1
# ['resnet50_summary', 'resnet18_summary']
# [2640, 1200]
# ========================================================================================================================
# ========================================================================================================================
# Set 1 time in network's cycle in using systolic array
# resnet50_summary
# [('64_64', 6600), ('128_128', 3300), ('256_256', 2640)]
# ========================================================================================================================
# resnet18_summary
# [('64_64', 3120), ('128_128', 1920), ('256_256', 1320)]
# ========================================================================================================================
# current systolic name : 256_256
# current layer's  idx and cycle : 2, 240
# ========================================================================================================================
# resnet50_summary's idx 2 get current remain cycle
# layer cycle 240
# ========================================================================================================================
# ========================================================================================================================
# resnet18_summary's idx 2 get current remain cycle
# layer cycle 120
# ========================================================================================================================
# 1
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [240 120]
# ========================================================================================================================
# closed systolic idx : 1 128_128, index 0
# Using cycle:  120
# ========================================================================================================================
# finish layer
# sys name : 128_128_0, network_name's_idx : resnet18_summary_2 finish
# ========================================================================================================================
# resnet50_summary
# ========================================================================================================================
# resnet50_summary's idx 2 get current remain cycle
# layer cycle 240 - 120 = 120
# 120
# ========================================================================================================================
# resnet18_summary
# finished layer
# ========================================================================================================================
# [('64_64', 3000), ('128_128', 1800), ('256_256', 1200)]
# ========================================================================================================================
# ========================================================================================================================
# using most powerful cycle in time  1
# ['resnet50_summary', 'resnet18_summary']
# [2400, 1200]
# ========================================================================================================================
# ========================================================================================================================
# Set 1 time in network's cycle in using systolic array
# resnet50_summary
# [('64_64', 6120), ('128_128', 3120), ('256_256', 2520)]
# ========================================================================================================================
# resnet18_summary
# [('64_64', 3000), ('128_128', 1800), ('256_256', 1200)]
# ========================================================================================================================
# current systolic name : 128_128
# current layer's  idx and cycle : 3, 240
# ========================================================================================================================
# resnet50_summary's idx 2 get current remain cycle
# layer cycle 120
# ========================================================================================================================
# ========================================================================================================================
# resnet18_summary's idx 3 get current remain cycle
# layer cycle 240
# ========================================================================================================================
# 0
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [120 240]
# ========================================================================================================================
# closed systolic idx : 0 256_256, index 0
# Using cycle:  120
# ========================================================================================================================
# finish layer
# sys name : 256_256_0, network_name's_idx : resnet50_summary_2 finish
# ========================================================================================================================
# resnet50_summary
# finished layer
# ========================================================================================================================
# [('64_64', 6000), ('128_128', 3000), ('256_256', 2400)]
# ========================================================================================================================
# resnet18_summary
# ========================================================================================================================
# resnet18_summary's idx 3 get current remain cycle
# layer cycle 240 - 120 = 120
# 120
# ========================================================================================================================
# ========================================================================================================================
# using most powerful cycle in time  1
# ['resnet50_summary', 'resnet18_summary']
# [2400, 1040]
# ========================================================================================================================
# ========================================================================================================================
# Set 1 time in network's cycle in using systolic array
# resnet50_summary
# [('64_64', 6000), ('128_128', 3000), ('256_256', 2400)]
# ========================================================================================================================
# resnet18_summary
# [('64_64', 2720), ('128_128', 1680), ('256_256', 1160)]
# ========================================================================================================================
# current systolic name : 256_256
# current layer's  idx and cycle : 3, 320
# ========================================================================================================================
# resnet50_summary's idx 3 get current remain cycle
# layer cycle 320
# ========================================================================================================================
# ========================================================================================================================
# resnet18_summary's idx 3 get current remain cycle
# layer cycle 120
# ========================================================================================================================
# 1
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [320 120]
# ========================================================================================================================
# closed systolic idx : 1 128_128, index 0
# Using cycle:  120
# ========================================================================================================================
# finish layer
# sys name : 128_128_0, network_name's_idx : resnet18_summary_3 finish
# ========================================================================================================================
# resnet50_summary
# ========================================================================================================================
# resnet50_summary's idx 3 get current remain cycle
# layer cycle 320 - 120 = 200
# 200
# ========================================================================================================================
# resnet18_summary
# finished layer
# ========================================================================================================================
# [('64_64', 2600), ('128_128', 1560), ('256_256', 1040)]
# ========================================================================================================================
# ========================================================================================================================
# using most powerful cycle in time  1
# ['resnet50_summary', 'resnet18_summary']
# [2080, 1040]
# ========================================================================================================================
# ========================================================================================================================
# Set 1 time in network's cycle in using systolic array
# resnet50_summary
# [('64_64', 5400), ('128_128', 2800), ('256_256', 2280)]
# ========================================================================================================================
# resnet18_summary
# [('64_64', 2600), ('128_128', 1560), ('256_256', 1040)]
# ========================================================================================================================
# current systolic name : 128_128
# current layer's  idx and cycle : 4, 300
# ========================================================================================================================
# resnet50_summary's idx 3 get current remain cycle
# layer cycle 200
# ========================================================================================================================
# ========================================================================================================================
# resnet18_summary's idx 4 get current remain cycle
# layer cycle 300
# ========================================================================================================================
# 0
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [200 300]
# ========================================================================================================================
# closed systolic idx : 0 256_256, index 0
# Using cycle:  200
# ========================================================================================================================
# finish layer
# sys name : 256_256_0, network_name's_idx : resnet50_summary_3 finish
# ========================================================================================================================
# resnet50_summary
# finished layer
# ========================================================================================================================
# [('64_64', 5200), ('128_128', 2600), ('256_256', 2080)]
# ========================================================================================================================
# resnet18_summary
# ========================================================================================================================
# resnet18_summary's idx 4 get current remain cycle
# layer cycle 300 - 200 = 100
# 100
# ========================================================================================================================
# ========================================================================================================================
# using most powerful cycle in time  1
# ['resnet50_summary', 'resnet18_summary']
# [2080, 840]
# ========================================================================================================================
# ========================================================================================================================
# Set 1 time in network's cycle in using systolic array
# resnet50_summary
# [('64_64', 5200), ('128_128', 2600), ('256_256', 2080)]
# ========================================================================================================================
# resnet18_summary
# [('64_64', 2200), ('128_128', 1360), ('256_256', 940)]
# ========================================================================================================================
# current systolic name : 256_256
# current layer's  idx and cycle : 4, 400
# ========================================================================================================================
# resnet50_summary's idx 4 get current remain cycle
# layer cycle 400
# ========================================================================================================================
# ========================================================================================================================
# resnet18_summary's idx 4 get current remain cycle
# layer cycle 100
# ========================================================================================================================
# 1
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [400 100]
# ========================================================================================================================
# closed systolic idx : 1 128_128, index 0
# Using cycle:  100
# ========================================================================================================================
# finish layer
# sys name : 128_128_0, network_name's_idx : resnet18_summary_4 finish
# ========================================================================================================================
# resnet50_summary
# ========================================================================================================================
# resnet50_summary's idx 4 get current remain cycle
# layer cycle 400 - 100 = 300
# 300
# ========================================================================================================================
# resnet18_summary
# finished layer
# ========================================================================================================================
# [('64_64', 2100), ('128_128', 1260), ('256_256', 840)]
# ========================================================================================================================
# ========================================================================================================================
# using most powerful cycle in time  1
# ['resnet50_summary', 'resnet18_summary']
# [1680, 840]
# ========================================================================================================================
# ========================================================================================================================
# Set 1 time in network's cycle in using systolic array
# resnet50_summary
# [('64_64', 4500), ('128_128', 2400), ('256_256', 1980)]
# ========================================================================================================================
# resnet18_summary
# [('64_64', 2100), ('128_128', 1260), ('256_256', 840)]
# ========================================================================================================================
# current systolic name : 128_128
# current layer's  idx and cycle : 5, 360
# ========================================================================================================================
# resnet50_summary's idx 4 get current remain cycle
# layer cycle 300
# ========================================================================================================================
# ========================================================================================================================
# resnet18_summary's idx 5 get current remain cycle
# layer cycle 360
# ========================================================================================================================
# 0
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [300 360]
# ========================================================================================================================
# closed systolic idx : 0 256_256, index 0
# Using cycle:  300
# ========================================================================================================================
# finish layer
# sys name : 256_256_0, network_name's_idx : resnet50_summary_4 finish
# ========================================================================================================================
# resnet50_summary
# finished layer
# ========================================================================================================================
# [('64_64', 4200), ('128_128', 2100), ('256_256', 1680)]
# ========================================================================================================================
# resnet18_summary
# ========================================================================================================================
# resnet18_summary's idx 5 get current remain cycle
# layer cycle 360 - 300 = 60
# 60
# ========================================================================================================================
# ========================================================================================================================
# using most powerful cycle in time  1
# ['resnet50_summary', 'resnet18_summary']
# [1680, 600]
# ========================================================================================================================
# ========================================================================================================================
# Set 1 time in network's cycle in using systolic array
# resnet50_summary
# [('64_64', 4200), ('128_128', 2100), ('256_256', 1680)]
# ========================================================================================================================
# resnet18_summary
# [('64_64', 1560), ('128_128', 960), ('256_256', 660)]
# ========================================================================================================================
# current systolic name : 256_256
# current layer's  idx and cycle : 5, 480
# ========================================================================================================================
# resnet50_summary's idx 5 get current remain cycle
# layer cycle 480
# ========================================================================================================================
# ========================================================================================================================
# resnet18_summary's idx 5 get current remain cycle
# layer cycle 60
# ========================================================================================================================
# 1
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [480  60]
# ========================================================================================================================
# closed systolic idx : 1 128_128, index 0
# Using cycle:  60
# ========================================================================================================================
# finish layer
# sys name : 128_128_0, network_name's_idx : resnet18_summary_5 finish
# ========================================================================================================================
# resnet50_summary
# ========================================================================================================================
# resnet50_summary's idx 5 get current remain cycle
# layer cycle 480 - 60 = 420
# 420
# ========================================================================================================================
# resnet18_summary
# finished layer
# ========================================================================================================================
# [('64_64', 1500), ('128_128', 900), ('256_256', 600)]
# ========================================================================================================================
# ========================================================================================================================
# using most powerful cycle in time  1
# ['resnet50_summary', 'resnet18_summary']
# [1200, 600]
# ========================================================================================================================
# ========================================================================================================================
# Set 1 time in network's cycle in using systolic array
# resnet50_summary
# [('64_64', 3420), ('128_128', 1920), ('256_256', 1620)]
# ========================================================================================================================
# resnet18_summary
# [('64_64', 1500), ('128_128', 900), ('256_256', 600)]
# ========================================================================================================================
# current systolic name : 128_128
# current layer's  idx and cycle : 6, 420
# ========================================================================================================================
# resnet50_summary's idx 5 get current remain cycle
# layer cycle 420
# ========================================================================================================================
# ========================================================================================================================
# resnet18_summary's idx 6 get current remain cycle
# layer cycle 420
# ========================================================================================================================
# 0
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [420 420]
# ========================================================================================================================
# closed systolic idx : 0 256_256, index 0
# Using cycle:  420
# ========================================================================================================================
# finish layer
# sys name : 256_256_0, network_name's_idx : resnet50_summary_5 finish
# ========================================================================================================================
# 1
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [420 420]
# ========================================================================================================================
# closed systolic idx : 1 128_128, index 0
# Using cycle:  420
# ========================================================================================================================
# finish layer
# sys name : 128_128_0, network_name's_idx : resnet18_summary_6 finish
# ========================================================================================================================
# resnet50_summary
# finished layer
# ========================================================================================================================
# [('64_64', 3000), ('128_128', 1500), ('256_256', 1200)]
# ========================================================================================================================
# resnet18_summary
# finished layer
# ========================================================================================================================
# [('64_64', 800), ('128_128', 480), ('256_256', 320)]
# ========================================================================================================================
# ========================================================================================================================
# using most powerful cycle in time  1
# ['resnet50_summary', 'resnet18_summary']
# [1200, 320]
# ========================================================================================================================
# ========================================================================================================================
# Set 1 time in network's cycle in using systolic array
# resnet50_summary
# [('64_64', 3000), ('128_128', 1500), ('256_256', 1200)]
# ========================================================================================================================
# resnet18_summary
# [('64_64', 800), ('128_128', 480), ('256_256', 320)]
# ========================================================================================================================
# current systolic name : 256_256
# current layer's  idx and cycle : 6, 560
# current systolic name : 128_128
# current layer's  idx and cycle : 7, 480
# ========================================================================================================================
# resnet50_summary's idx 6 get current remain cycle
# layer cycle 560
# ========================================================================================================================
# ========================================================================================================================
# resnet18_summary's idx 7 get current remain cycle
# layer cycle 480
# ========================================================================================================================
# 1
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [560 480]
# ========================================================================================================================
# closed systolic idx : 1 128_128, index 0
# Using cycle:  480
# ========================================================================================================================
# finish layer
# sys name : 128_128_0, network_name's_idx : resnet18_summary_7 finish
# ========================================================================================================================
# resnet50_summary
# ========================================================================================================================
# resnet50_summary's idx 6 get current remain cycle
# layer cycle 560 - 480 = 80
# 80
# ========================================================================================================================
# resnet18_summary
# finished layer
# ========================================================================================================================
# [('64_64', 0), ('128_128', 0), ('256_256', 0)]
# ========================================================================================================================
# ****************************************************************************************************************************************************************
# finished network :  resnet18_summary
# remove network
# ****************************************************************************************************************************************************************
# ========================================================================================================================
# using most powerful cycle in time  1
# ['resnet50_summary']
# [640]
# ========================================================================================================================
# ========================================================================================================================
# Set 1 time in network's cycle in using systolic array
# resnet50_summary
# [('64_64', 1680), ('128_128', 880), ('256_256', 720)]
# ========================================================================================================================
# ========================================================================================================================
# resnet50_summary's idx 6 get current remain cycle
# layer cycle 80
# ========================================================================================================================
# 0
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [80]
# ========================================================================================================================
# closed systolic idx : 0 256_256, index 0
# Using cycle:  80
# ========================================================================================================================
# finish layer
# sys name : 256_256_0, network_name's_idx : resnet50_summary_6 finish
# ========================================================================================================================
# resnet50_summary
# finished layer
# ========================================================================================================================
# [('64_64', 1600), ('128_128', 800), ('256_256', 640)]
# ========================================================================================================================
# ========================================================================================================================
# using most powerful cycle in time  0
# ['resnet50_summary']
# [640]
# ========================================================================================================================
# ========================================================================================================================
# Set 0 time in network's cycle in using systolic array
# resnet50_summary
# [('64_64', 1600), ('128_128', 800), ('256_256', 640)]
# ========================================================================================================================
# current systolic name : 256_256
# current layer's  idx and cycle : 7, 640
# ========================================================================================================================
# resnet50_summary's idx 7 get current remain cycle
# layer cycle 640
# ========================================================================================================================
# 0
# ========================================================================================================================
# current layer cycle in systolic array
# ['256_256_0', '128_128_0', '64_64_2', '64_64_1', '64_64_0']
# [640]
# ========================================================================================================================
# closed systolic idx : 0 256_256, index 0
# Using cycle:  640
# ========================================================================================================================
# finish layer
# sys name : 256_256_0, network_name's_idx : resnet50_summary_7 finish
# ========================================================================================================================
# resnet50_summary
# finished layer
# ========================================================================================================================
# [('64_64', 0), ('128_128', 0), ('256_256', 0)]
# ========================================================================================================================
# ****************************************************************************************************************************************************************
# finished network :  resnet50_summary
# remove network
# ****************************************************************************************************************************************************************
# ########## finish entire layer ################
# total using cycle :
# ########## finish entire layer ################
# ########## finish entire layer ################
# total using cycle :
# ########## finish entire layer ################
# ########## finish entire layer ################
# total using cycle :
# ########## finish entire layer ################
# ########## finish entire layer ################
# total using cycle :
# ########## finish entire layer ################
# ########## finish entire layer ################
# total using cycle :
# ########## finish entire layer ################

# %%
output_cycle
# Out:
# [80, 40, 120, 60, 180, 60, 260, 40, 360, 420, 60, 560, 640]

# %%
def set_layer_to_sys(list_network, sys_list):
    for sys in sys_list:

# %%
network.network_cycle['64_64']
# Out:
# [2519349504,
#  158454240,
#  158454240,
#  158454240,
#  158454240,
#  20220144,
#  20671728,
#  20671728,
#  20671728,
#  2959992,
#  3411576,
#  3411576,
#  3411576,
#  799288,
#  1260088,
#  1260088,
#  1260088,
#  10320]

# %%
a = [1,1,2,3]
b = np.array([1, 1, 2, 3])
np.argmin(a)
where = np.where(b>=3)
print(where)
print(b[where[0]])
# Out:
# (array([3]),)
# [3]

# %%
for i in b[where[0]]:
    print(i)
# Out:
# 3
